# %%
println("This is Julia Code")
# Out:
# This is Julia Code

# %%
using Karnak
using NetworkLayout
using Colors
using Luxor
using Graphs

# %%
G = loadgraph("SimpleGridgraph.lg")
# Out:
# {20, 88} directed simple Int64 graph

# %%
@drawsvg begin
    background("black")
    sethue("grey40")
    fontsize(8)
    drawgraph(G, 
        layout=stress, 
        vertexlabels = 1:nv(G),
        vertexfillcolors = 
            [RGB(rand(3)/2...) 
               for i in 1:nv(G)]
    )
end 1000 800
